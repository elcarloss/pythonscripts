# %%
import ipywidgets as wg
from IPython.display import display

# %%
name = wg.Text(value='Service Name')
env = widgets.RadioButtons(
          options=['prod', 'test', 'dev'],
          description='Environment: ',
          disabled=False
          )

# %%
display(name,env)

# %%
display(name)
